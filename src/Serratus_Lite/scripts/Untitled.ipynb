# %%
import pandas as pd

# %%
x = pd.DataFrame([['a', 'b'], ['c', 'd']], columns=['letter', 'number'])
y = pd.DataFrame([['a', '1'], ['c', '2'], ['e', 3]], columns=['letter', 'number'])

# %%
z = x.merge(y, left_on='letter', right_on='letter', how='inner')
z
# Out:
#        number_x number_y
# letter
# a             b        1
# c             d        2

# %%
x = x.set_index('letter')
x
# Out:
#        number
# letter
# a           b
# c           d

# %%
y = y.set_index('letter')
y
# Out:
#        number
# letter
# a           1
# c           2
# e           3
